# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
counter =collections.Counter(text)
chars = sorted(counter.keys())
###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) 
# first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]
###

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([193646])
# context is >a< target is >r<
# context is >ar< target is >s<
# context is >ars< target is > <
# context is >ars < target is >1<
# context is >ars 1< target is >8<
# context is >ars 18< target is >5<
# context is >ars 185< target is >4<
# context is >ars 1854< target is >.<

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    #
    ix = torch.randint(len(data) - block_size, (batch_size,))

    # select batch_size starting points in the data, store them in a list called starting_points
    x = torch.stack([data[i:i+block_size] for i in ix])

    # x is the sequence of integer starting at each straing point and of length block_size
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])

    # y is the character after each starting position

    ### 
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        probs = torch.randn(vocab_size, vocab_size)
        self.embedding = nn.Embedding(vocab_size, vocab_size)

        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.embedding(idx)

        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)


            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx
vocab_size = len(chars) # vocab_size is vocab_size
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 4.917657852172852

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))
## YOUR CODE HERE
p = torch.tensor([encode(['\n'])], dtype=torch.long).to(device)
print(decode(m.generate(p, max_new_tokens=100)[0].tolist()))


###
# Out:
# [0]
#
# VËu s le t Ila ·ÊS[7a ffa!  pllusu,
# ÀùZù qu n  l'or s tèriz
# Qh, es mbr  lisafâç·PAgHA'mest ceun.
# Vla

# %% [markdown]
# La phrase générée est aléatoire, ne suit pas de structure grammaticale. C'est parce que le modèle n'a pas été entrainé.né. Il faut donc lui fournir des données pour qu'il puisse apprendre à prédire le caractère suivant dans une phrase.

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.1842, val loss 5.1063
# step 10: train loss 5.1734, val loss 5.1847
# step 20: train loss 5.1017, val loss 5.1524
# step 30: train loss 5.1642, val loss 5.1565
# step 40: train loss 4.9975, val loss 5.0782
# step 50: train loss 5.0532, val loss 5.1050
# step 60: train loss 5.0715, val loss 5.1010
# step 70: train loss 5.0625, val loss 5.0200
# step 80: train loss 5.0525, val loss 5.0398
# step 90: train loss 5.0491, val loss 5.0893
# step 100: train loss 5.0072, val loss 5.0807
# step 110: train loss 5.0213, val loss 4.9796
# step 120: train loss 5.0438, val loss 5.0386
# step 130: train loss 5.0629, val loss 5.0158
# step 140: train loss 5.0178, val loss 5.0348
# step 150: train loss 4.9935, val loss 4.9667
# step 160: train loss 4.9404, val loss 5.0386
# step 170: train loss 4.9714, val loss 4.9806
# step 180: train loss 4.9464, val loss 5.0405
# step 190: train loss 4.9672, val loss 5.0551
# step 200: train loss 4.9150, val loss 4.9624
# step 210: train loss 4.9681, val loss 4.9315
# step 220: train loss 4.8985, val loss 4.9025
# step 230: train loss 4.9846, val loss 4.9394
# step 240: train loss 4.9009, val loss 4.9112
# step 250: train loss 4.8910, val loss 4.8658
# step 260: train loss 4.9062, val loss 4.8974
# step 270: train loss 4.8319, val loss 4.9265
# step 280: train loss 4.8673, val loss 4.9290
# step 290: train loss 4.8529, val loss 4.9161
# step 300: train loss 4.8327, val loss 4.8724
# step 310: train loss 4.8649, val loss 4.9332
# step 320: train loss 4.8559, val loss 4.9426
# step 330: train loss 4.8361, val loss 4.8443
# step 340: train loss 4.7903, val loss 4.8856
# step 350: train loss 4.7746, val loss 4.7973
# step 360: train loss 4.8191, val loss 4.8568
# step 370: train loss 4.8108, val loss 4.8399
# step 380: train loss 4.8145, val loss 4.8736
# step 390: train loss 4.7690, val loss 4.8671
# step 400: train loss 4.7591, val loss 4.8838
# step 410: train loss 4.7547, val loss 4.8560
# step 420: train loss 4.6733, val loss 4.7584
# step 430: train loss 4.6775, val loss 4.7992
# step 440: train loss 4.7420, val loss 4.7736
# step 450: train loss 4.7830, val loss 4.7800
# step 460: train loss 4.6841, val loss 4.7796
# step 470: train loss 4.7294, val loss 4.7567
# step 480: train loss 4.6777, val loss 4.7268
# step 490: train loss 4.7574, val loss 4.7266
# step 500: train loss 4.6294, val loss 4.7420
# step 510: train loss 4.7061, val loss 4.7281
# step 520: train loss 4.6708, val loss 4.7548
# step 530: train loss 4.6541, val loss 4.7262
# step 540: train loss 4.6678, val loss 4.6989
# step 550: train loss 4.6969, val loss 4.7509
# step 560: train loss 4.6496, val loss 4.7422
# step 570: train loss 4.5601, val loss 4.6120
# step 580: train loss 4.6356, val loss 4.7285
# step 590: train loss 4.5849, val loss 4.6939
# step 600: train loss 4.6278, val loss 4.6975
# step 610: train loss 4.5989, val loss 4.6463
# step 620: train loss 4.6114, val loss 4.6636
# step 630: train loss 4.5509, val loss 4.6854
# step 640: train loss 4.5354, val loss 4.5962
# step 650: train loss 4.5572, val loss 4.5783
# step 660: train loss 4.5349, val loss 4.5372
# step 670: train loss 4.5274, val loss 4.6497
# step 680: train loss 4.5720, val loss 4.5856
# step 690: train loss 4.5489, val loss 4.5692
# step 700: train loss 4.5928, val loss 4.6410
# step 710: train loss 4.5100, val loss 4.6307
# step 720: train loss 4.4552, val loss 4.5591
# step 730: train loss 4.5355, val loss 4.5284
# step 740: train loss 4.4870, val loss 4.6421
# step 750: train loss 4.4533, val loss 4.5538
# step 760: train loss 4.4626, val loss 4.5939
# step 770: train loss 4.4956, val loss 4.6043
# step 780: train loss 4.4341, val loss 4.5256
# step 790: train loss 4.4908, val loss 4.5105
# step 800: train loss 4.4903, val loss 4.5126
# step 810: train loss 4.4240, val loss 4.5085
# step 820: train loss 4.4149, val loss 4.4811
# step 830: train loss 4.4079, val loss 4.4884
# step 840: train loss 4.4594, val loss 4.4662
# step 850: train loss 4.4236, val loss 4.4740
# step 860: train loss 4.3772, val loss 4.5204
# step 870: train loss 4.4078, val loss 4.4076
# step 880: train loss 4.4062, val loss 4.4516
# step 890: train loss 4.4271, val loss 4.5095
# step 900: train loss 4.3846, val loss 4.4889
# step 910: train loss 4.3709, val loss 4.3869
# step 920: train loss 4.3678, val loss 4.3766
# step 930: train loss 4.3524, val loss 4.4445
# step 940: train loss 4.3037, val loss 4.4192
# step 950: train loss 4.3391, val loss 4.4335
# step 960: train loss 4.4239, val loss 4.3547
# step 970: train loss 4.3305, val loss 4.3907
# step 980: train loss 4.2967, val loss 4.4274
# step 990: train loss 4.3410, val loss 4.3482
# step 1000: train loss 4.2994, val loss 4.3833
# step 1010: train loss 4.3109, val loss 4.3625
# step 1020: train loss 4.2451, val loss 4.3843
# step 1030: train loss 4.3059, val loss 4.4011
# step 1040: train loss 4.2426, val loss 4.3248
# step 1050: train loss 4.2316, val loss 4.3708
# step 1060: train loss 4.2413, val loss 4.4069
# step 1070: train loss 4.2839, val loss 4.3832
# step 1080: train loss 4.2813, val loss 4.3031
# step 1090: train loss 4.2298, val loss 4.3479
# step 1100: train loss 4.2629, val loss 4.3632
# step 1110: train loss 4.2207, val loss 4.3550
# step 1120: train loss 4.2307, val loss 4.3507
# step 1130: train loss 4.2320, val loss 4.2813
# step 1140: train loss 4.2163, val loss 4.2831
# step 1150: train loss 4.2010, val loss 4.2310
# step 1160: train loss 4.2479, val loss 4.2824
# step 1170: train loss 4.2171, val loss 4.2941
# step 1180: train loss 4.1861, val loss 4.3291
# step 1190: train loss 4.2195, val loss 4.2667
# step 1200: train loss 4.1593, val loss 4.1757
# step 1210: train loss 4.1849, val loss 4.3123
# step 1220: train loss 4.1946, val loss 4.1783
# step 1230: train loss 4.1995, val loss 4.3272
# step 1240: train loss 4.1303, val loss 4.2639
# step 1250: train loss 4.1352, val loss 4.2481
# step 1260: train loss 4.1399, val loss 4.1942
# step 1270: train loss 4.0680, val loss 4.2674
# step 1280: train loss 4.1430, val loss 4.2000
# step 1290: train loss 4.0511, val loss 4.1511
# step 1300: train loss 4.1086, val loss 4.1403
# step 1310: train loss 4.1133, val loss 4.2248
# step 1320: train loss 4.1014, val loss 4.1376
# step 1330: train loss 4.0562, val loss 4.1938
# step 1340: train loss 4.0996, val loss 4.1417
# step 1350: train loss 4.1389, val loss 4.1760
# step 1360: train loss 4.1071, val loss 4.2117
# step 1370: train loss 4.0317, val loss 4.1322
# step 1380: train loss 4.0595, val loss 4.0912
# step 1390: train loss 4.0687, val loss 4.0769
# step 1400: train loss 4.0102, val loss 4.0886
# step 1410: train loss 4.0479, val loss 4.1270
# step 1420: train loss 4.1378, val loss 4.0455
# step 1430: train loss 4.0465, val loss 4.1138
# step 1440: train loss 3.9874, val loss 4.0471
# step 1450: train loss 4.0140, val loss 4.0887
# step 1460: train loss 4.0284, val loss 4.0434
# step 1470: train loss 4.0163, val loss 4.0427
# step 1480: train loss 4.0498, val loss 4.0777
# step 1490: train loss 4.0274, val loss 4.0880
# step 1500: train loss 4.0198, val loss 4.0630
# step 1510: train loss 3.9296, val loss 4.0024
# step 1520: train loss 3.9219, val loss 4.0197
# step 1530: train loss 3.9953, val loss 4.1002
# step 1540: train loss 3.9995, val loss 4.0344
# step 1550: train loss 3.9611, val loss 4.0106
# step 1560: train loss 3.8531, val loss 4.0047
# step 1570: train loss 4.0003, val loss 4.0227
# step 1580: train loss 3.9123, val loss 4.0762
# step 1590: train loss 3.9634, val loss 4.0767
# step 1600: train loss 3.9456, val loss 4.0033
# step 1610: train loss 3.8823, val loss 3.8664
# step 1620: train loss 3.9527, val loss 3.9980
# step 1630: train loss 3.8585, val loss 3.9687
# step 1640: train loss 3.9199, val loss 4.0017
# step 1650: train loss 3.8697, val loss 3.9897
# step 1660: train loss 3.8685, val loss 3.9998
# step 1670: train loss 3.8617, val loss 3.9528
# step 1680: train loss 3.8730, val loss 3.9908
# step 1690: train loss 3.8902, val loss 4.0222
# step 1700: train loss 3.8059, val loss 3.9456
# step 1710: train loss 3.8705, val loss 3.9952
# step 1720: train loss 3.8751, val loss 3.9625
# step 1730: train loss 3.8586, val loss 3.9284
# step 1740: train loss 3.9274, val loss 3.8839
# step 1750: train loss 3.8378, val loss 3.9269
# step 1760: train loss 3.7614, val loss 3.9482
# step 1770: train loss 3.8631, val loss 3.8719
# step 1780: train loss 3.7617, val loss 3.8979
# step 1790: train loss 3.8290, val loss 3.9142
# step 1800: train loss 3.8478, val loss 3.9048
# step 1810: train loss 3.7835, val loss 3.8989
# step 1820: train loss 3.8012, val loss 3.8560
# step 1830: train loss 3.7493, val loss 3.8658
# step 1840: train loss 3.7859, val loss 3.8791
# step 1850: train loss 3.8174, val loss 3.9257
# step 1860: train loss 3.8023, val loss 3.8997
# step 1870: train loss 3.7674, val loss 3.8024
# step 1880: train loss 3.7761, val loss 3.7807
# step 1890: train loss 3.7898, val loss 3.8325
# step 1900: train loss 3.7474, val loss 3.8812
# step 1910: train loss 3.7822, val loss 3.7779
# step 1920: train loss 3.7424, val loss 3.8522
# step 1930: train loss 3.7662, val loss 3.8839
# step 1940: train loss 3.7198, val loss 3.8571
# step 1950: train loss 3.7494, val loss 3.7165
# step 1960: train loss 3.6763, val loss 3.8113
# step 1970: train loss 3.6429, val loss 3.7705
# step 1980: train loss 3.7219, val loss 3.7256
# step 1990: train loss 3.6660, val loss 3.8543
# step 2000: train loss 3.7075, val loss 3.8086
# step 2010: train loss 3.6917, val loss 3.8036
# step 2020: train loss 3.6632, val loss 3.8227
# step 2030: train loss 3.6523, val loss 3.7539
# step 2040: train loss 3.6854, val loss 3.7348
# step 2050: train loss 3.7378, val loss 3.7474
# step 2060: train loss 3.6548, val loss 3.7585
# step 2070: train loss 3.6524, val loss 3.8063
# step 2080: train loss 3.6725, val loss 3.6898
# step 2090: train loss 3.6778, val loss 3.8493
# step 2100: train loss 3.6530, val loss 3.7578
# step 2110: train loss 3.6824, val loss 3.7415
# step 2120: train loss 3.7356, val loss 3.7665
# step 2130: train loss 3.6675, val loss 3.7838
# step 2140: train loss 3.6966, val loss 3.8075
# step 2150: train loss 3.6256, val loss 3.7465
# step 2160: train loss 3.6262, val loss 3.7185
# step 2170: train loss 3.6066, val loss 3.6942
# step 2180: train loss 3.6261, val loss 3.6372
# step 2190: train loss 3.6331, val loss 3.7608
# step 2200: train loss 3.5734, val loss 3.5887
# step 2210: train loss 3.6108, val loss 3.6410
# step 2220: train loss 3.6162, val loss 3.7172
# step 2230: train loss 3.5224, val loss 3.7223
# step 2240: train loss 3.6016, val loss 3.7011
# step 2250: train loss 3.6283, val loss 3.6753
# step 2260: train loss 3.6069, val loss 3.7707
# step 2270: train loss 3.6084, val loss 3.7272
# step 2280: train loss 3.6489, val loss 3.6549
# step 2290: train loss 3.5238, val loss 3.6317
# step 2300: train loss 3.5340, val loss 3.6499
# step 2310: train loss 3.6078, val loss 3.7501
# step 2320: train loss 3.5833, val loss 3.7408
# step 2330: train loss 3.5335, val loss 3.5795
# step 2340: train loss 3.5640, val loss 3.6719
# step 2350: train loss 3.5611, val loss 3.5766
# step 2360: train loss 3.5350, val loss 3.6906
# step 2370: train loss 3.6176, val loss 3.5912
# step 2380: train loss 3.5264, val loss 3.7376
# step 2390: train loss 3.6139, val loss 3.5486
# step 2400: train loss 3.4963, val loss 3.6167
# step 2410: train loss 3.5469, val loss 3.6375
# step 2420: train loss 3.5299, val loss 3.5352
# step 2430: train loss 3.5696, val loss 3.6388
# step 2440: train loss 3.5409, val loss 3.6487
# step 2450: train loss 3.5940, val loss 3.5482
# step 2460: train loss 3.4963, val loss 3.5306
# step 2470: train loss 3.5210, val loss 3.6744
# step 2480: train loss 3.4918, val loss 3.5980
# step 2490: train loss 3.5543, val loss 3.6330
# step 2500: train loss 3.4155, val loss 3.6302
# step 2510: train loss 3.5123, val loss 3.6093
# step 2520: train loss 3.5316, val loss 3.5423
# step 2530: train loss 3.4376, val loss 3.5417
# step 2540: train loss 3.5201, val loss 3.5721
# step 2550: train loss 3.4626, val loss 3.5821
# step 2560: train loss 3.3967, val loss 3.5745
# step 2570: train loss 3.4918, val loss 3.5051
# step 2580: train loss 3.4198, val loss 3.5446
# step 2590: train loss 3.4246, val loss 3.6430
# step 2600: train loss 3.4523, val loss 3.6056
# step 2610: train loss 3.4055, val loss 3.5096
# step 2620: train loss 3.5183, val loss 3.5572
# step 2630: train loss 3.4532, val loss 3.5229
# step 2640: train loss 3.4620, val loss 3.5423
# step 2650: train loss 3.4677, val loss 3.5384
# step 2660: train loss 3.3651, val loss 3.5752
# step 2670: train loss 3.4394, val loss 3.5145
# step 2680: train loss 3.3106, val loss 3.5595
# step 2690: train loss 3.3989, val loss 3.5108
# step 2700: train loss 3.3759, val loss 3.5104
# step 2710: train loss 3.4922, val loss 3.4704
# step 2720: train loss 3.4005, val loss 3.4880
# step 2730: train loss 3.4556, val loss 3.4193
# step 2740: train loss 3.3882, val loss 3.5003
# step 2750: train loss 3.4212, val loss 3.4221
# step 2760: train loss 3.3653, val loss 3.4746
# step 2770: train loss 3.3811, val loss 3.4017
# step 2780: train loss 3.4314, val loss 3.4328
# step 2790: train loss 3.4139, val loss 3.3626
# step 2800: train loss 3.2948, val loss 3.5819
# step 2810: train loss 3.4130, val loss 3.3678
# step 2820: train loss 3.3818, val loss 3.5247
# step 2830: train loss 3.3106, val loss 3.4485
# step 2840: train loss 3.2846, val loss 3.4586
# step 2850: train loss 3.3716, val loss 3.5417
# step 2860: train loss 3.3570, val loss 3.3836
# step 2870: train loss 3.3364, val loss 3.5706
# step 2880: train loss 3.3321, val loss 3.4183
# step 2890: train loss 3.2822, val loss 3.3528
# step 2900: train loss 3.3141, val loss 3.5274
# step 2910: train loss 3.3296, val loss 3.4607
# step 2920: train loss 3.4162, val loss 3.3261
# step 2930: train loss 3.2779, val loss 3.4590
# step 2940: train loss 3.2963, val loss 3.4925
# step 2950: train loss 3.2961, val loss 3.4123
# step 2960: train loss 3.2837, val loss 3.3593
# step 2970: train loss 3.2714, val loss 3.4600
# step 2980: train loss 3.2279, val loss 3.3685
# step 2990: train loss 3.3062, val loss 3.3895
# step 3000: train loss 3.2452, val loss 3.4716
# step 3010: train loss 3.2729, val loss 3.3827
# step 3020: train loss 3.2485, val loss 3.3004
# step 3030: train loss 3.3815, val loss 3.3774
# step 3040: train loss 3.1418, val loss 3.5023
# step 3050: train loss 3.3183, val loss 3.3150
# step 3060: train loss 3.3149, val loss 3.4378
# step 3070: train loss 3.2799, val loss 3.3887
# step 3080: train loss 3.2914, val loss 3.4122
# step 3090: train loss 3.2289, val loss 3.4347
# step 3100: train loss 3.2692, val loss 3.4807
# step 3110: train loss 3.3293, val loss 3.3276
# step 3120: train loss 3.2794, val loss 3.4030
# step 3130: train loss 3.2441, val loss 3.4262
# step 3140: train loss 3.2422, val loss 3.2314
# step 3150: train loss 3.3196, val loss 3.3280
# step 3160: train loss 3.2966, val loss 3.4071
# step 3170: train loss 3.2270, val loss 3.2890
# step 3180: train loss 3.2169, val loss 3.3357
# step 3190: train loss 3.2627, val loss 3.3787
# step 3200: train loss 3.2731, val loss 3.3967
# step 3210: train loss 3.1861, val loss 3.4039
# step 3220: train loss 3.1220, val loss 3.2496
# step 3230: train loss 3.2280, val loss 3.3444
# step 3240: train loss 3.2771, val loss 3.3703
# step 3250: train loss 3.2601, val loss 3.2698
# step 3260: train loss 3.1738, val loss 3.3576
# step 3270: train loss 3.1376, val loss 3.1619
# step 3280: train loss 3.2161, val loss 3.4153
# step 3290: train loss 3.2570, val loss 3.2317
# step 3300: train loss 3.1512, val loss 3.3629
# step 3310: train loss 3.2291, val loss 3.3963
# step 3320: train loss 3.2758, val loss 3.2975
# step 3330: train loss 3.2457, val loss 3.2398
# step 3340: train loss 3.2702, val loss 3.3564
# step 3350: train loss 3.1633, val loss 3.2224
# step 3360: train loss 3.2453, val loss 3.3298
# step 3370: train loss 3.1293, val loss 3.1793
# step 3380: train loss 3.1294, val loss 3.2331
# step 3390: train loss 3.1182, val loss 3.2796
# step 3400: train loss 3.2289, val loss 3.1962
# step 3410: train loss 3.0856, val loss 3.3000
# step 3420: train loss 3.2184, val loss 3.1549
# step 3430: train loss 3.1722, val loss 3.2286
# step 3440: train loss 3.1530, val loss 3.3831
# step 3450: train loss 3.1618, val loss 3.2496
# step 3460: train loss 3.1135, val loss 3.2798
# step 3470: train loss 3.0660, val loss 3.2009
# step 3480: train loss 3.2034, val loss 3.2626
# step 3490: train loss 3.0632, val loss 3.2540
# step 3500: train loss 3.1381, val loss 3.3377
# step 3510: train loss 3.1706, val loss 3.2899
# step 3520: train loss 3.2016, val loss 3.2977
# step 3530: train loss 3.1220, val loss 3.2653
# step 3540: train loss 3.0651, val loss 3.2248
# step 3550: train loss 3.1640, val loss 3.2866
# step 3560: train loss 3.0818, val loss 3.2472
# step 3570: train loss 3.0621, val loss 3.1818
# step 3580: train loss 3.1561, val loss 3.2482
# step 3590: train loss 3.1234, val loss 3.1391
# step 3600: train loss 3.0461, val loss 3.2782
# step 3610: train loss 3.1217, val loss 3.1683
# step 3620: train loss 3.0902, val loss 3.2206
# step 3630: train loss 3.1188, val loss 3.2588
# step 3640: train loss 3.1620, val loss 3.1895
# step 3650: train loss 3.1325, val loss 3.1405
# step 3660: train loss 3.0830, val loss 3.1778
# step 3670: train loss 3.1655, val loss 3.3175
# step 3680: train loss 3.0429, val loss 3.1422
# step 3690: train loss 3.1174, val loss 3.1482
# step 3700: train loss 3.1067, val loss 3.2524
# step 3710: train loss 3.1544, val loss 3.1874
# step 3720: train loss 3.0285, val loss 3.1830
# step 3730: train loss 3.0554, val loss 3.0767
# step 3740: train loss 3.1440, val loss 3.1559
# step 3750: train loss 3.0871, val loss 3.2037
# step 3760: train loss 3.0397, val loss 3.1827
# step 3770: train loss 3.1088, val loss 3.2075
# step 3780: train loss 3.1120, val loss 3.2379
# step 3790: train loss 3.0524, val loss 3.1803
# step 3800: train loss 3.1434, val loss 3.1536
# step 3810: train loss 2.9721, val loss 3.1668
# step 3820: train loss 3.0500, val loss 3.2332
# step 3830: train loss 3.0715, val loss 3.2084
# step 3840: train loss 3.0126, val loss 3.0692
# step 3850: train loss 3.0729, val loss 3.1368
# step 3860: train loss 3.0538, val loss 3.2288
# step 3870: train loss 3.0459, val loss 3.1873
# step 3880: train loss 3.0977, val loss 3.0857
# step 3890: train loss 3.0464, val loss 3.1484
# step 3900: train loss 3.1326, val loss 3.1788
# step 3910: train loss 3.0090, val loss 3.0969
# step 3920: train loss 3.0305, val loss 3.1130
# step 3930: train loss 3.0710, val loss 3.1181
# step 3940: train loss 3.0015, val loss 3.1794
# step 3950: train loss 3.0939, val loss 3.1228
# step 3960: train loss 3.1049, val loss 3.1639
# step 3970: train loss 3.0092, val loss 3.0716
# step 3980: train loss 3.0398, val loss 3.2002
# step 3990: train loss 3.0629, val loss 3.1257
# step 4000: train loss 3.0177, val loss 3.0315
# step 4010: train loss 3.0241, val loss 3.0861
# step 4020: train loss 3.0109, val loss 3.0788
# step 4030: train loss 3.0468, val loss 3.1045
# step 4040: train loss 2.9637, val loss 3.0985
# step 4050: train loss 2.9697, val loss 3.1114
# step 4060: train loss 2.9500, val loss 3.1551
# step 4070: train loss 2.9856, val loss 3.0305
# step 4080: train loss 3.0027, val loss 3.0551
# step 4090: train loss 2.9806, val loss 3.0988
# step 4100: train loss 2.9782, val loss 3.0803
# step 4110: train loss 2.9474, val loss 3.0906
# step 4120: train loss 2.9888, val loss 3.0568
# step 4130: train loss 2.9709, val loss 3.0988
# step 4140: train loss 2.9941, val loss 3.1483
# step 4150: train loss 2.9592, val loss 3.0649
# step 4160: train loss 3.0181, val loss 3.2617
# step 4170: train loss 2.9730, val loss 3.0159
# step 4180: train loss 2.9279, val loss 3.1034
# step 4190: train loss 3.0069, val loss 3.1166
# step 4200: train loss 2.9488, val loss 3.0285
# step 4210: train loss 2.9600, val loss 3.0621
# step 4220: train loss 2.9488, val loss 3.0657
# step 4230: train loss 2.9795, val loss 2.9060
# step 4240: train loss 2.9046, val loss 3.0110
# step 4250: train loss 3.0124, val loss 2.9610
# step 4260: train loss 2.8632, val loss 3.0970
# step 4270: train loss 2.9605, val loss 3.0249
# step 4280: train loss 2.9554, val loss 3.0377
# step 4290: train loss 3.0089, val loss 3.0037
# step 4300: train loss 2.8636, val loss 3.0018
# step 4310: train loss 3.0011, val loss 2.9588
# step 4320: train loss 2.8914, val loss 3.1027
# step 4330: train loss 2.9788, val loss 3.0547
# step 4340: train loss 2.9838, val loss 3.0588
# step 4350: train loss 2.9085, val loss 3.0293
# step 4360: train loss 2.9791, val loss 3.0567
# step 4370: train loss 2.9029, val loss 2.9875
# step 4380: train loss 2.9816, val loss 3.0858
# step 4390: train loss 2.9559, val loss 3.0004
# step 4400: train loss 2.8279, val loss 3.0564
# step 4410: train loss 3.0191, val loss 3.0439
# step 4420: train loss 2.8806, val loss 3.1332
# step 4430: train loss 2.8868, val loss 2.9916
# step 4440: train loss 2.9589, val loss 3.0441
# step 4450: train loss 2.9422, val loss 3.0902
# step 4460: train loss 2.9826, val loss 2.9241
# step 4470: train loss 2.9898, val loss 3.1593
# step 4480: train loss 2.9711, val loss 3.0220
# step 4490: train loss 2.8662, val loss 2.9589
# step 4500: train loss 2.8613, val loss 3.0851
# step 4510: train loss 2.9867, val loss 2.9923
# step 4520: train loss 2.8498, val loss 3.0257
# step 4530: train loss 2.9949, val loss 3.0611
# step 4540: train loss 2.8613, val loss 3.0557
# step 4550: train loss 2.9759, val loss 3.0425
# step 4560: train loss 2.9121, val loss 2.9938
# step 4570: train loss 2.8915, val loss 3.0610
# step 4580: train loss 2.8490, val loss 2.9064
# step 4590: train loss 2.9122, val loss 2.9002
# step 4600: train loss 2.8716, val loss 2.9537
# step 4610: train loss 2.8659, val loss 3.1105
# step 4620: train loss 2.7885, val loss 3.0279
# step 4630: train loss 2.8921, val loss 2.9951
# step 4640: train loss 2.9560, val loss 3.0018
# step 4650: train loss 2.8519, val loss 3.0171
# step 4660: train loss 2.8529, val loss 2.9791
# step 4670: train loss 2.8380, val loss 3.1048
# step 4680: train loss 2.8861, val loss 3.0424
# step 4690: train loss 2.8991, val loss 3.0449
# step 4700: train loss 2.9712, val loss 3.0123
# step 4710: train loss 2.9268, val loss 2.8696
# step 4720: train loss 2.8465, val loss 2.9505
# step 4730: train loss 2.8527, val loss 3.0169
# step 4740: train loss 2.8572, val loss 2.9985
# step 4750: train loss 2.8578, val loss 2.9479
# step 4760: train loss 2.8951, val loss 2.9132
# step 4770: train loss 2.8951, val loss 2.9707
# step 4780: train loss 2.9322, val loss 3.0207
# step 4790: train loss 2.7635, val loss 2.8914
# step 4800: train loss 3.0164, val loss 3.0137
# step 4810: train loss 2.8877, val loss 2.9251
# step 4820: train loss 2.8604, val loss 2.8862
# step 4830: train loss 2.7931, val loss 2.9501
# step 4840: train loss 2.8716, val loss 2.8743
# step 4850: train loss 2.7857, val loss 3.0551
# step 4860: train loss 2.8574, val loss 3.0276
# step 4870: train loss 2.8689, val loss 2.8948
# step 4880: train loss 2.8805, val loss 2.9530
# step 4890: train loss 2.8629, val loss 2.9693
# step 4900: train loss 2.9165, val loss 2.8832
# step 4910: train loss 2.8331, val loss 2.9421
# step 4920: train loss 2.8001, val loss 3.1012
# step 4930: train loss 2.8551, val loss 2.9042
# step 4940: train loss 2.8437, val loss 2.9708
# step 4950: train loss 2.7784, val loss 2.9683
# step 4960: train loss 2.8692, val loss 2.8618
# step 4970: train loss 2.8464, val loss 2.9668
# step 4980: train loss 2.8326, val loss 2.9452
# step 4990: train loss 2.8409, val loss 2.9368
# step 5000: train loss 2.8351, val loss 2.8841
# step 5010: train loss 2.7967, val loss 2.8382
# step 5020: train loss 2.8548, val loss 2.9839
# step 5030: train loss 2.8855, val loss 2.9616
# step 5040: train loss 2.7887, val loss 2.8029
# step 5050: train loss 2.8034, val loss 2.8671
# step 5060: train loss 2.8222, val loss 2.9672
# step 5070: train loss 2.8679, val loss 2.8416
# step 5080: train loss 2.8520, val loss 2.8439
# step 5090: train loss 2.8510, val loss 2.9159
# step 5100: train loss 2.8713, val loss 2.9227
# step 5110: train loss 2.8375, val loss 2.8642
# step 5120: train loss 2.7485, val loss 2.9065
# step 5130: train loss 2.7848, val loss 2.8431
# step 5140: train loss 2.8271, val loss 2.9408
# step 5150: train loss 2.8251, val loss 2.9004
# step 5160: train loss 2.8405, val loss 2.9691
# step 5170: train loss 2.8760, val loss 2.8828
# step 5180: train loss 2.7880, val loss 2.9503
# step 5190: train loss 2.8235, val loss 2.9202
# step 5200: train loss 2.7960, val loss 2.9505
# step 5210: train loss 2.8170, val loss 2.8862
# step 5220: train loss 2.7849, val loss 2.9633
# step 5230: train loss 2.8260, val loss 2.9134
# step 5240: train loss 2.7424, val loss 2.9567
# step 5250: train loss 2.7792, val loss 2.9555
# step 5260: train loss 2.7339, val loss 2.8713
# step 5270: train loss 2.7997, val loss 2.8234
# step 5280: train loss 2.8308, val loss 2.9535
# step 5290: train loss 2.7441, val loss 3.0182
# step 5300: train loss 2.7953, val loss 2.9946
# step 5310: train loss 2.8249, val loss 2.8554
# step 5320: train loss 2.8086, val loss 2.9703
# step 5330: train loss 2.8211, val loss 2.8941
# step 5340: train loss 2.7539, val loss 2.8058
# step 5350: train loss 2.7333, val loss 2.8684
# step 5360: train loss 2.7637, val loss 2.8254
# step 5370: train loss 2.7344, val loss 2.9296
# step 5380: train loss 2.8377, val loss 2.8240
# step 5390: train loss 2.8119, val loss 2.8120
# step 5400: train loss 2.7548, val loss 2.7911
# step 5410: train loss 2.8709, val loss 2.7845
# step 5420: train loss 2.7178, val loss 2.8710
# step 5430: train loss 2.8449, val loss 2.8550
# step 5440: train loss 2.6978, val loss 2.8714
# step 5450: train loss 2.7825, val loss 2.9412
# step 5460: train loss 2.8548, val loss 2.8257
# step 5470: train loss 2.8236, val loss 2.8947
# step 5480: train loss 2.8566, val loss 2.7906
# step 5490: train loss 2.7845, val loss 2.8493
# step 5500: train loss 2.8065, val loss 2.8336
# step 5510: train loss 2.7560, val loss 2.8416
# step 5520: train loss 2.7470, val loss 2.8034
# step 5530: train loss 2.7576, val loss 2.8238
# step 5540: train loss 2.7662, val loss 2.8722
# step 5550: train loss 2.7905, val loss 2.9103
# step 5560: train loss 2.7322, val loss 2.8588
# step 5570: train loss 2.7393, val loss 2.7928
# step 5580: train loss 2.7708, val loss 2.8495
# step 5590: train loss 2.7746, val loss 2.7867
# step 5600: train loss 2.7660, val loss 2.9718
# step 5610: train loss 2.6644, val loss 2.8567
# step 5620: train loss 2.7487, val loss 2.7952
# step 5630: train loss 2.7343, val loss 2.8265
# step 5640: train loss 2.7469, val loss 2.7891
# step 5650: train loss 2.7224, val loss 2.9646
# step 5660: train loss 2.7188, val loss 2.8454
# step 5670: train loss 2.8085, val loss 2.8747
# step 5680: train loss 2.7805, val loss 2.7925
# step 5690: train loss 2.6357, val loss 2.8501
# step 5700: train loss 2.7410, val loss 2.8190
# step 5710: train loss 2.7259, val loss 2.8227
# step 5720: train loss 2.7074, val loss 2.9203
# step 5730: train loss 2.6853, val loss 2.8565
# step 5740: train loss 2.7530, val loss 2.8124
# step 5750: train loss 2.8027, val loss 2.8162
# step 5760: train loss 2.7040, val loss 2.8932
# step 5770: train loss 2.7500, val loss 2.7512
# step 5780: train loss 2.8241, val loss 2.7901
# step 5790: train loss 2.8329, val loss 2.7871
# step 5800: train loss 2.6982, val loss 2.8903
# step 5810: train loss 2.6749, val loss 2.9139
# step 5820: train loss 2.7221, val loss 2.9229
# step 5830: train loss 2.6626, val loss 2.7795
# step 5840: train loss 2.7919, val loss 2.8290
# step 5850: train loss 2.7257, val loss 2.7971
# step 5860: train loss 2.7902, val loss 2.7284
# step 5870: train loss 2.6530, val loss 2.7342
# step 5880: train loss 2.7513, val loss 2.8694
# step 5890: train loss 2.6850, val loss 2.8525
# step 5900: train loss 2.6495, val loss 2.6976
# step 5910: train loss 2.7088, val loss 2.6744
# step 5920: train loss 2.6816, val loss 2.7825
# step 5930: train loss 2.7509, val loss 2.8311
# step 5940: train loss 2.7224, val loss 2.7874
# step 5950: train loss 2.8917, val loss 2.8202
# step 5960: train loss 2.7220, val loss 2.9562
# step 5970: train loss 2.7020, val loss 2.7463
# step 5980: train loss 2.7633, val loss 2.8021
# step 5990: train loss 2.6984, val loss 2.7958
# step 6000: train loss 2.7316, val loss 2.8022
# step 6010: train loss 2.6420, val loss 2.9344
# step 6020: train loss 2.7178, val loss 2.7789
# step 6030: train loss 2.6350, val loss 2.6884
# step 6040: train loss 2.6861, val loss 2.7280
# step 6050: train loss 2.8445, val loss 2.8136
# step 6060: train loss 2.6836, val loss 2.8363
# step 6070: train loss 2.6802, val loss 2.8219
# step 6080: train loss 2.6319, val loss 2.7286
# step 6090: train loss 2.7913, val loss 2.7970
# step 6100: train loss 2.6961, val loss 2.8337
# step 6110: train loss 2.7617, val loss 2.8011
# step 6120: train loss 2.7907, val loss 2.7916
# step 6130: train loss 2.7199, val loss 2.8543
# step 6140: train loss 2.6997, val loss 2.8147
# step 6150: train loss 2.7157, val loss 2.8594
# step 6160: train loss 2.6630, val loss 2.8613
# step 6170: train loss 2.8285, val loss 2.7818
# step 6180: train loss 2.7370, val loss 2.7931
# step 6190: train loss 2.6873, val loss 2.8322
# step 6200: train loss 2.6848, val loss 2.7200
# step 6210: train loss 2.6826, val loss 2.7973
# step 6220: train loss 2.8143, val loss 2.7592
# step 6230: train loss 2.6793, val loss 2.7946
# step 6240: train loss 2.7254, val loss 2.7820
# step 6250: train loss 2.6744, val loss 2.8386
# step 6260: train loss 2.7358, val loss 2.6832
# step 6270: train loss 2.6748, val loss 2.9191
# step 6280: train loss 2.6622, val loss 2.8065
# step 6290: train loss 2.6597, val loss 2.8717
# step 6300: train loss 2.6751, val loss 2.7602
# step 6310: train loss 2.6608, val loss 2.8320
# step 6320: train loss 2.6832, val loss 2.7651
# step 6330: train loss 2.6982, val loss 2.7928
# step 6340: train loss 2.7065, val loss 2.8388
# step 6350: train loss 2.7409, val loss 2.7130
# step 6360: train loss 2.7785, val loss 2.7543
# step 6370: train loss 2.6861, val loss 2.7354
# step 6380: train loss 2.6634, val loss 2.7765
# step 6390: train loss 2.5661, val loss 2.7299
# step 6400: train loss 2.6367, val loss 2.6506
# step 6410: train loss 2.7741, val loss 2.8021
# step 6420: train loss 2.6709, val loss 2.7311
# step 6430: train loss 2.6974, val loss 2.7158
# step 6440: train loss 2.6787, val loss 2.7105
# step 6450: train loss 2.6224, val loss 2.7691
# step 6460: train loss 2.6999, val loss 2.7153
# step 6470: train loss 2.7083, val loss 2.6861
# step 6480: train loss 2.7637, val loss 2.6079
# step 6490: train loss 2.6420, val loss 2.7038
# step 6500: train loss 2.6499, val loss 2.7478
# step 6510: train loss 2.5708, val loss 2.6921
# step 6520: train loss 2.6096, val loss 2.7891
# step 6530: train loss 2.7459, val loss 2.7165
# step 6540: train loss 2.6765, val loss 2.6358
# step 6550: train loss 2.6121, val loss 2.8158
# step 6560: train loss 2.6619, val loss 2.7911
# step 6570: train loss 2.7196, val loss 2.7608
# step 6580: train loss 2.6979, val loss 2.8369
# step 6590: train loss 2.6180, val loss 2.8016
# step 6600: train loss 2.7390, val loss 2.7499
# step 6610: train loss 2.6499, val loss 2.7128
# step 6620: train loss 2.7102, val loss 2.7709
# step 6630: train loss 2.6613, val loss 2.7347
# step 6640: train loss 2.6880, val loss 2.7814
# step 6650: train loss 2.6966, val loss 2.7155
# step 6660: train loss 2.5936, val loss 2.7704
# step 6670: train loss 2.6460, val loss 2.7153
# step 6680: train loss 2.6550, val loss 2.6946
# step 6690: train loss 2.6468, val loss 2.7606
# step 6700: train loss 2.6776, val loss 2.7858
# step 6710: train loss 2.5715, val loss 2.7590
# step 6720: train loss 2.6518, val loss 2.6783
# step 6730: train loss 2.6440, val loss 2.6567
# step 6740: train loss 2.6146, val loss 2.6902
# step 6750: train loss 2.6695, val loss 2.7239
# step 6760: train loss 2.6761, val loss 2.7182
# step 6770: train loss 2.7053, val loss 2.6265
# step 6780: train loss 2.6701, val loss 2.6089
# step 6790: train loss 2.6891, val loss 2.8285
# step 6800: train loss 2.6174, val loss 2.7901
# step 6810: train loss 2.6728, val loss 2.7401
# step 6820: train loss 2.6932, val loss 2.6074
# step 6830: train loss 2.6153, val loss 2.7261
# step 6840: train loss 2.6549, val loss 2.7074
# step 6850: train loss 2.6674, val loss 2.7505
# step 6860: train loss 2.6073, val loss 2.8787
# step 6870: train loss 2.6779, val loss 2.8063
# step 6880: train loss 2.6357, val loss 2.7933
# step 6890: train loss 2.6453, val loss 2.8942
# step 6900: train loss 2.6177, val loss 2.7246
# step 6910: train loss 2.5322, val loss 2.7826
# step 6920: train loss 2.5720, val loss 2.7145
# step 6930: train loss 2.6856, val loss 2.7062
# step 6940: train loss 2.5898, val loss 2.7416
# step 6950: train loss 2.5971, val loss 2.8746
# step 6960: train loss 2.6770, val loss 2.7036
# step 6970: train loss 2.5800, val loss 2.7779
# step 6980: train loss 2.6123, val loss 2.7195
# step 6990: train loss 2.6744, val loss 2.7127
# step 7000: train loss 2.6115, val loss 2.7961
# step 7010: train loss 2.6575, val loss 2.6646
# step 7020: train loss 2.5755, val loss 2.6209
# step 7030: train loss 2.6272, val loss 2.7257
# step 7040: train loss 2.5786, val loss 2.7288
# step 7050: train loss 2.6403, val loss 2.8115
# step 7060: train loss 2.6128, val loss 2.6791
# step 7070: train loss 2.6486, val loss 2.8239
# step 7080: train loss 2.5791, val loss 2.7790
# step 7090: train loss 2.6197, val loss 2.7323
# step 7100: train loss 2.5839, val loss 2.7677
# step 7110: train loss 2.6058, val loss 2.6552
# step 7120: train loss 2.6301, val loss 2.7390
# step 7130: train loss 2.6379, val loss 2.7847
# step 7140: train loss 2.5451, val loss 2.7593
# step 7150: train loss 2.6459, val loss 2.6352
# step 7160: train loss 2.6520, val loss 2.7984
# step 7170: train loss 2.6715, val loss 2.6588
# step 7180: train loss 2.6617, val loss 2.7782
# step 7190: train loss 2.6280, val loss 2.6302
# step 7200: train loss 2.5328, val loss 2.7989
# step 7210: train loss 2.6605, val loss 2.8168
# step 7220: train loss 2.5685, val loss 2.6620
# step 7230: train loss 2.5734, val loss 2.6628
# step 7240: train loss 2.5293, val loss 2.7747
# step 7250: train loss 2.5734, val loss 2.6800
# step 7260: train loss 2.6697, val loss 2.7416
# step 7270: train loss 2.6385, val loss 2.7369
# step 7280: train loss 2.6246, val loss 2.7048
# step 7290: train loss 2.5561, val loss 2.6078
# step 7300: train loss 2.6749, val loss 2.6506
# step 7310: train loss 2.6032, val loss 2.7946
# step 7320: train loss 2.5682, val loss 2.6520
# step 7330: train loss 2.6045, val loss 2.5573
# step 7340: train loss 2.5667, val loss 2.6941
# step 7350: train loss 2.6051, val loss 2.7146
# step 7360: train loss 2.6218, val loss 2.6881
# step 7370: train loss 2.5834, val loss 2.6824
# step 7380: train loss 2.6420, val loss 2.7847
# step 7390: train loss 2.5723, val loss 2.6605
# step 7400: train loss 2.6249, val loss 2.7164
# step 7410: train loss 2.6818, val loss 2.6305
# step 7420: train loss 2.6307, val loss 2.6871
# step 7430: train loss 2.5738, val loss 2.6801
# step 7440: train loss 2.6095, val loss 2.7467
# step 7450: train loss 2.6211, val loss 2.6036
# step 7460: train loss 2.5671, val loss 2.7768
# step 7470: train loss 2.6127, val loss 2.6430
# step 7480: train loss 2.6071, val loss 2.6574
# step 7490: train loss 2.6506, val loss 2.6520
# step 7500: train loss 2.5168, val loss 2.6391
# step 7510: train loss 2.5839, val loss 2.7290
# step 7520: train loss 2.6073, val loss 2.6426
# step 7530: train loss 2.5959, val loss 2.6683
# step 7540: train loss 2.5982, val loss 2.6740
# step 7550: train loss 2.6388, val loss 2.6646
# step 7560: train loss 2.5550, val loss 2.5766
# step 7570: train loss 2.6077, val loss 2.5856
# step 7580: train loss 2.5526, val loss 2.7444
# step 7590: train loss 2.5929, val loss 2.6645
# step 7600: train loss 2.6328, val loss 2.7252
# step 7610: train loss 2.6123, val loss 2.6415
# step 7620: train loss 2.6510, val loss 2.6270
# step 7630: train loss 2.5857, val loss 2.6133
# step 7640: train loss 2.5592, val loss 2.6003
# step 7650: train loss 2.6050, val loss 2.7053
# step 7660: train loss 2.5648, val loss 2.7129
# step 7670: train loss 2.5998, val loss 2.6952
# step 7680: train loss 2.6765, val loss 2.5473
# step 7690: train loss 2.5774, val loss 2.6685
# step 7700: train loss 2.6327, val loss 2.6050
# step 7710: train loss 2.6113, val loss 2.6666
# step 7720: train loss 2.5862, val loss 2.6358
# step 7730: train loss 2.5540, val loss 2.7539
# step 7740: train loss 2.6765, val loss 2.7205
# step 7750: train loss 2.5553, val loss 2.6302
# step 7760: train loss 2.5081, val loss 2.6699
# step 7770: train loss 2.6449, val loss 2.6696
# step 7780: train loss 2.5068, val loss 2.6621
# step 7790: train loss 2.6124, val loss 2.7433
# step 7800: train loss 2.6529, val loss 2.6838
# step 7810: train loss 2.5572, val loss 2.7256
# step 7820: train loss 2.5021, val loss 2.6239
# step 7830: train loss 2.5395, val loss 2.7243
# step 7840: train loss 2.5743, val loss 2.6788
# step 7850: train loss 2.5462, val loss 2.7302
# step 7860: train loss 2.6135, val loss 2.7153
# step 7870: train loss 2.6525, val loss 2.6282
# step 7880: train loss 2.6776, val loss 2.6465
# step 7890: train loss 2.6235, val loss 2.5837
# step 7900: train loss 2.5724, val loss 2.6465
# step 7910: train loss 2.6201, val loss 2.6980
# step 7920: train loss 2.6259, val loss 2.6310
# step 7930: train loss 2.5212, val loss 2.7774
# step 7940: train loss 2.6042, val loss 2.6241
# step 7950: train loss 2.5692, val loss 2.6383
# step 7960: train loss 2.5743, val loss 2.7643
# step 7970: train loss 2.5847, val loss 2.7340
# step 7980: train loss 2.5252, val loss 2.5796
# step 7990: train loss 2.5923, val loss 2.6565
# step 8000: train loss 2.5299, val loss 2.6659
# step 8010: train loss 2.5476, val loss 2.7025
# step 8020: train loss 2.5510, val loss 2.7168
# step 8030: train loss 2.4521, val loss 2.6544
# step 8040: train loss 2.5628, val loss 2.5791
# step 8050: train loss 2.5711, val loss 2.7921
# step 8060: train loss 2.5340, val loss 2.5488
# step 8070: train loss 2.5767, val loss 2.6540
# step 8080: train loss 2.6073, val loss 2.6697
# step 8090: train loss 2.5627, val loss 2.5410
# step 8100: train loss 2.6153, val loss 2.6328
# step 8110: train loss 2.5844, val loss 2.6873
# step 8120: train loss 2.5672, val loss 2.6329
# step 8130: train loss 2.5852, val loss 2.7633
# step 8140: train loss 2.5945, val loss 2.5948
# step 8150: train loss 2.6138, val loss 2.6256
# step 8160: train loss 2.5216, val loss 2.7646
# step 8170: train loss 2.5591, val loss 2.7094
# step 8180: train loss 2.5902, val loss 2.6941
# step 8190: train loss 2.4703, val loss 2.5778
# step 8200: train loss 2.5784, val loss 2.5384
# step 8210: train loss 2.6403, val loss 2.6874
# step 8220: train loss 2.4713, val loss 2.6987
# step 8230: train loss 2.5277, val loss 2.5758
# step 8240: train loss 2.5486, val loss 2.6236
# step 8250: train loss 2.5491, val loss 2.6582
# step 8260: train loss 2.4627, val loss 2.5979
# step 8270: train loss 2.5688, val loss 2.5349
# step 8280: train loss 2.5126, val loss 2.7536
# step 8290: train loss 2.5649, val loss 2.6748
# step 8300: train loss 2.5704, val loss 2.6520
# step 8310: train loss 2.5522, val loss 2.7045
# step 8320: train loss 2.5813, val loss 2.6462
# step 8330: train loss 2.6183, val loss 2.6110
# step 8340: train loss 2.6181, val loss 2.5864
# step 8350: train loss 2.5570, val loss 2.7851
# step 8360: train loss 2.5716, val loss 2.7237
# step 8370: train loss 2.5557, val loss 2.5895
# step 8380: train loss 2.5664, val loss 2.7147
# step 8390: train loss 2.6499, val loss 2.6216
# step 8400: train loss 2.6005, val loss 2.6633
# step 8410: train loss 2.5457, val loss 2.6217
# step 8420: train loss 2.5454, val loss 2.5234
# step 8430: train loss 2.6365, val loss 2.5343
# step 8440: train loss 2.5382, val loss 2.6534
# step 8450: train loss 2.6272, val loss 2.5925
# step 8460: train loss 2.5563, val loss 2.7110
# step 8470: train loss 2.5215, val loss 2.6997
# step 8480: train loss 2.5626, val loss 2.6855
# step 8490: train loss 2.5304, val loss 2.6019
# step 8500: train loss 2.5701, val loss 2.7379
# step 8510: train loss 2.5837, val loss 2.6108
# step 8520: train loss 2.5125, val loss 2.5909
# step 8530: train loss 2.5233, val loss 2.6488
# step 8540: train loss 2.5460, val loss 2.5755
# step 8550: train loss 2.5888, val loss 2.5911
# step 8560: train loss 2.5041, val loss 2.5652
# step 8570: train loss 2.5195, val loss 2.6257
# step 8580: train loss 2.5161, val loss 2.6813
# step 8590: train loss 2.5142, val loss 2.5563
# step 8600: train loss 2.5303, val loss 2.6140
# step 8610: train loss 2.6241, val loss 2.6090
# step 8620: train loss 2.5612, val loss 2.7194
# step 8630: train loss 2.5019, val loss 2.5999
# step 8640: train loss 2.4876, val loss 2.6979
# step 8650: train loss 2.5389, val loss 2.5859
# step 8660: train loss 2.5460, val loss 2.5181
# step 8670: train loss 2.5480, val loss 2.6124
# step 8680: train loss 2.5285, val loss 2.5888
# step 8690: train loss 2.5146, val loss 2.6086
# step 8700: train loss 2.5391, val loss 2.6480
# step 8710: train loss 2.5841, val loss 2.5529
# step 8720: train loss 2.5696, val loss 2.5366
# step 8730: train loss 2.5720, val loss 2.6355
# step 8740: train loss 2.6333, val loss 2.6626
# step 8750: train loss 2.5116, val loss 2.6949
# step 8760: train loss 2.5437, val loss 2.5196
# step 8770: train loss 2.5815, val loss 2.5502
# step 8780: train loss 2.5131, val loss 2.6544
# step 8790: train loss 2.5642, val loss 2.6319
# step 8800: train loss 2.5538, val loss 2.6221
# step 8810: train loss 2.5942, val loss 2.5859
# step 8820: train loss 2.5072, val loss 2.5780
# step 8830: train loss 2.5209, val loss 2.7425
# step 8840: train loss 2.5122, val loss 2.7045
# step 8850: train loss 2.5284, val loss 2.5604
# step 8860: train loss 2.4276, val loss 2.5371
# step 8870: train loss 2.4901, val loss 2.6182
# step 8880: train loss 2.4787, val loss 2.7003
# step 8890: train loss 2.5730, val loss 2.5592
# step 8900: train loss 2.5638, val loss 2.6167
# step 8910: train loss 2.4855, val loss 2.6586
# step 8920: train loss 2.4944, val loss 2.5559
# step 8930: train loss 2.5001, val loss 2.5620
# step 8940: train loss 2.4300, val loss 2.6443
# step 8950: train loss 2.5135, val loss 2.6728
# step 8960: train loss 2.5345, val loss 2.5678
# step 8970: train loss 2.5105, val loss 2.6316
# step 8980: train loss 2.4981, val loss 2.5630
# step 8990: train loss 2.5117, val loss 2.5422
# step 9000: train loss 2.5171, val loss 2.4716
# step 9010: train loss 2.6121, val loss 2.5527
# step 9020: train loss 2.5539, val loss 2.6408
# step 9030: train loss 2.5683, val loss 2.6451
# step 9040: train loss 2.5309, val loss 2.6374
# step 9050: train loss 2.5346, val loss 2.5021
# step 9060: train loss 2.4836, val loss 2.6059
# step 9070: train loss 2.5430, val loss 2.5814
# step 9080: train loss 2.5092, val loss 2.5664
# step 9090: train loss 2.4881, val loss 2.6568
# step 9100: train loss 2.6150, val loss 2.6760
# step 9110: train loss 2.4624, val loss 2.5744
# step 9120: train loss 2.4823, val loss 2.6047
# step 9130: train loss 2.5041, val loss 2.5582
# step 9140: train loss 2.4202, val loss 2.5687
# step 9150: train loss 2.4487, val loss 2.6382
# step 9160: train loss 2.4486, val loss 2.5207
# step 9170: train loss 2.4790, val loss 2.6875
# step 9180: train loss 2.5159, val loss 2.5314
# step 9190: train loss 2.4932, val loss 2.6039
# step 9200: train loss 2.5457, val loss 2.5962
# step 9210: train loss 2.4441, val loss 2.6812
# step 9220: train loss 2.5273, val loss 2.6567
# step 9230: train loss 2.5054, val loss 2.5624
# step 9240: train loss 2.6257, val loss 2.5787
# step 9250: train loss 2.6315, val loss 2.6210
# step 9260: train loss 2.4364, val loss 2.5133
# step 9270: train loss 2.4211, val loss 2.5280
# step 9280: train loss 2.4334, val loss 2.6043
# step 9290: train loss 2.5223, val loss 2.6095
# step 9300: train loss 2.5289, val loss 2.5480
# step 9310: train loss 2.6559, val loss 2.4922
# step 9320: train loss 2.5917, val loss 2.6191
# step 9330: train loss 2.5221, val loss 2.6631
# step 9340: train loss 2.5229, val loss 2.5560
# step 9350: train loss 2.5273, val loss 2.6187
# step 9360: train loss 2.4829, val loss 2.5008
# step 9370: train loss 2.5358, val loss 2.6592
# step 9380: train loss 2.5169, val loss 2.5030
# step 9390: train loss 2.5838, val loss 2.6287
# step 9400: train loss 2.4393, val loss 2.5423
# step 9410: train loss 2.5112, val loss 2.7196
# step 9420: train loss 2.4686, val loss 2.5067
# step 9430: train loss 2.5264, val loss 2.6187
# step 9440: train loss 2.4693, val loss 2.5838
# step 9450: train loss 2.4814, val loss 2.6086
# step 9460: train loss 2.4833, val loss 2.5714
# step 9470: train loss 2.5903, val loss 2.7160
# step 9480: train loss 2.4889, val loss 2.5041
# step 9490: train loss 2.5266, val loss 2.6633
# step 9500: train loss 2.4827, val loss 2.6028
# step 9510: train loss 2.5112, val loss 2.5293
# step 9520: train loss 2.5687, val loss 2.6001
# step 9530: train loss 2.5054, val loss 2.5449
# step 9540: train loss 2.5513, val loss 2.5515
# step 9550: train loss 2.5424, val loss 2.5373
# step 9560: train loss 2.4910, val loss 2.5323
# step 9570: train loss 2.4419, val loss 2.7633
# step 9580: train loss 2.4649, val loss 2.5566
# step 9590: train loss 2.4911, val loss 2.5584
# step 9600: train loss 2.4977, val loss 2.6630
# step 9610: train loss 2.4508, val loss 2.5895
# step 9620: train loss 2.3985, val loss 2.5210
# step 9630: train loss 2.5162, val loss 2.5325
# step 9640: train loss 2.5203, val loss 2.5944
# step 9650: train loss 2.4924, val loss 2.6017
# step 9660: train loss 2.5097, val loss 2.5225
# step 9670: train loss 2.4180, val loss 2.5444
# step 9680: train loss 2.5215, val loss 2.5197
# step 9690: train loss 2.4822, val loss 2.6096
# step 9700: train loss 2.5188, val loss 2.5172
# step 9710: train loss 2.5135, val loss 2.5715
# step 9720: train loss 2.4394, val loss 2.5261
# step 9730: train loss 2.5137, val loss 2.5353
# step 9740: train loss 2.5372, val loss 2.6553
# step 9750: train loss 2.4645, val loss 2.5437
# step 9760: train loss 2.5375, val loss 2.5731
# step 9770: train loss 2.4098, val loss 2.6500
# step 9780: train loss 2.4592, val loss 2.6200
# step 9790: train loss 2.5202, val loss 2.6279
# step 9800: train loss 2.4482, val loss 2.5610
# step 9810: train loss 2.5164, val loss 2.6120
# step 9820: train loss 2.4853, val loss 2.5549
# step 9830: train loss 2.5253, val loss 2.5780
# step 9840: train loss 2.4581, val loss 2.5827
# step 9850: train loss 2.4572, val loss 2.7048
# step 9860: train loss 2.5290, val loss 2.5607
# step 9870: train loss 2.5591, val loss 2.5078
# step 9880: train loss 2.4947, val loss 2.6398
# step 9890: train loss 2.5157, val loss 2.6059
# step 9900: train loss 2.5458, val loss 2.5616
# step 9910: train loss 2.5015, val loss 2.5270
# step 9920: train loss 2.4893, val loss 2.5688
# step 9930: train loss 2.4789, val loss 2.5153
# step 9940: train loss 2.4816, val loss 2.5497
# step 9950: train loss 2.4573, val loss 2.5487
# step 9960: train loss 2.4713, val loss 2.5620
# step 9970: train loss 2.5422, val loss 2.6033
# step 9980: train loss 2.5106, val loss 2.5989
# step 9990: train loss 2.5256, val loss 2.7119

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# 'mesé SLendet fr s de voyss  HwH0kî veasonstte son ta  Dmetoùy, qudi lan'uiaienforédontumes---ja----à

# %% [markdown]
# C'est mieux, même si on peut faire encore mieux, c'est déjà pas mal, certains mots sont corrects!

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
print(weights0 == weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])
# tensor([[True, True, True, True, True, True, True, True],
#         [True, True, True, True, True, True, True, True],
#         [True, True, True, True, True, True, True, True],
#         [True, True, True, True, True, True, True, True],
#         [True, True, True, True, True, True, True, True],
#         [True, True, True, True, True, True, True, True],
#         [True, True, True, True, True, True, True, True],
#         [True, True, True, True, True, True, True, True]])

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE

# Define the number of heads
num_heads = C // head_size

# Define the Key layer
key = torch.nn.Linear(C, head_size)
# Define the Query layer
query = torch.nn.Linear(C,head_size)
# Define the Value layer
value = torch.nn.Linear(C, head_size)

# Apply each layer to the input
k = key(x)
q = query(x)
v = value(x)  # (B, num_heads, T, head_size)

# Compute the normalized product between Q and K
weights = torch.matmul(q, k.transpose(-2, -1)) / C**0.5 # (B, num_heads, T, T)

# Apply the mask (lower triangular matrix)
tril = torch.tril(torch.ones(T, T))
weights = weights.masked_fill(tril == 0, float('-inf'))

# Apply the softmax
weights = torch.nn.functional.softmax(weights, dim=-1)

# Compute the output
out = torch.matmul(weights, v)  # (B, num_heads, T, head_size)

# Print the result
print(weights[0])
print(out[0])
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.4178, 0.5822, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3901, 0.2241, 0.3858, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3344, 0.2121, 0.2613, 0.1922, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.1828, 0.2610, 0.2432, 0.1894, 0.1236, 0.0000, 0.0000, 0.0000],
#         [0.1859, 0.1404, 0.1796, 0.1679, 0.1715, 0.1547, 0.0000, 0.0000],
#         [0.1976, 0.0627, 0.0993, 0.0843, 0.2769, 0.1349, 0.1443, 0.0000],
#         [0.1122, 0.1029, 0.1185, 0.1267, 0.1401, 0.1276, 0.1254, 0.1465]],
#        grad_fn=<SelectBackward0>)
# tensor([[ 0.6763,  0.1754,  0.4186,  0.5782,  0.5791, -0.3108,  1.1324, -0.3307,
#          -0.7066,  0.6418, -0.3000, -0.2965,  0.0367, -0.0460,  1.0944,  0.0998],
#         [-0.1004, -0.0662, -0.6449, -0.0543,  0.3833, -0.0619,  0.6112, -0.3079,
#           0.0396,  0.2942, -0.0530, -0.2317,  0.0603, -0.0884,  0.3321,  0.1022],
#         [ 0.0739,  0.1175,  0.2332,  0.0713,  0.4900,  0.0902,  0.2138, -0.1882,
#          -0.5161,  0.2735, -0.3812, -0.2960,  0.1135,  0.1971,  0.6669, -0.1233],
#         [-0.0109,  0.0378,  0.1030,  0.2102,  0.3363,  0.1424,  0.2518, -0.3279,
#          -0.5136,  0.1217, -0.3445, -0.2890, -0.0012,  0.2138,  0.6530,  0.1225],
#         [-0.1461, -0.0469, -0.1044,  0.0889,  0.3089,  0.0734,  0.1519, -0.2244,
#          -0.4349,  0.0646, -0.3471, -0.2545,  0.0659,  0.1573,  0.4628,  0.0312],
#         [-0.1065, -0.0974, -0.1590,  0.0846,  0.3021, -0.0585,  0.1646, -0.1900,
#          -0.4058, -0.0587, -0.2737, -0.3354,  0.0736,  0.1357,  0.4286,  0.0270],
#         [-0.0252, -0.1353, -0.0342,  0.2042,  0.3632, -0.1904,  0.2078, -0.1664,
#          -0.5720, -0.0557, -0.2374, -0.0388,  0.1016,  0.1337,  0.3419, -0.0257],
#         [-0.2598, -0.1116,  0.0097,  0.1894,  0.2457, -0.0081,  0.1106, -0.3091,
#          -0.4212, -0.0568, -0.1356, -0.0871,  0.1562,  0.1896,  0.3837,  0.1560]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1585, val loss 2.1808

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1288, val loss 2.1219

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
